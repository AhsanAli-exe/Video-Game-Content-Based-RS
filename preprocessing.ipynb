# %%
import pandas as pd
import numpy as np
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from scipy import sparse
import re

# %%
df = pd.read_csv('games.csv')
df.sample(10)
# Out:
#        Unnamed: 0                                              Title  \
# 4888         4888                      Little Nemo: The Dream Master
# 6117         6117                           Puffy no P.S. I Love You
# 50198       50198  Sword Art Online: Fatal Bullet - Dissonance of...
# 14726       14726                          Neighbourhood Necromancer
# 12314       12314                                  Belief & Betrayal
# 46397       46397                                           Footsies
# 36505       36505                        Martian Gothic: Unification
# 51012       51012                                             Togges
# 13537       13537                Kingdom Hearts Re:Chain of Memories
# 14628       14628                                    Treasure Hunter
#
#        Release_Date                               Developers  \
# 4888   Sep 01, 1990                               ['Capcom']
# 6117            TBD                                       []
# 50198  Jan 18, 2019  ['Dimps', 'Bandai Namco Entertainment']
# 14726  May 12, 2017                      ['Choice of Games']
# 12314           TBD                                       []
# 46397  Jul 11, 2018                              ['HiFight']
# 36505  May 04, 2000                                       []
# 51012  Dec 07, 2022         ['Thunderful', 'Regular Studio']
# 13537  Dec 02, 2008                          ['Square Enix']
# 14628  May 17, 2018                                       []
#
#                                                  Summary  \
# 4888   Little Nemo: The Dream Master is a platform ga...
# 6117     Fan disc of the band Puffy (AKA Puffy Ami Yumi)
# 50198  Dissonance of the Nexus Expansion takes place ...
# 14726  Command the undead to take revenge on the subu...
# 12314  A point and click adventure game influenced he...
# 46397  FOOTSIES is a 2D fighting game where players c...
# 36505  Martian Gothic : Unification is one of the num...
# 51012  Togges is a collect-a-thon 3D Platformer about...
# 13537  Kingdom Hearts Re:Chain of Memories is a full ...
# 14628  Dive into the exciting world of finding long f...
#
#                                                Platforms  \
# 4888                                             ['NES']
# 6117                                                  []
# 50198        ['Windows PC', 'PlayStation 4', 'Xbox One']
# 14726                     ['Windows PC', 'Mac', 'Linux']
# 12314                                                 []
# 46397                   ['Windows PC', 'Android', 'iOS']
# 36505                      ['Windows PC', 'PlayStation']
# 51012  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...
# 13537  ['Windows PC', 'PlayStation 4', 'PlayStation 3...
# 14628                                     ['Windows PC']
#
#                                              Genres  Rating Plays Playing  \
# 4888                      ['Adventure', 'Platform']     3.3   276       2
# 6117                                      ['Music']     NaN     0       0
# 50198                                       ['RPG']     NaN     2       0
# 14726                 ['Adventure', 'Indie', 'RPG']     NaN     2       0
# 12314                                 ['Adventure']     NaN     1       0
# 46397                                  ['Fighting']     3.4    92       1
# 36505                                 ['Adventure']     2.3    30       1
# 51012  ['Adventure', 'Indie', 'Platform', 'Puzzle']     3.3     6       2
# 13537                          ['Adventure', 'RPG']     2.8   291      12
# 14628                        ['Indie', 'Simulator']     NaN     3       0
#
#       Backlogs Wishlist Lists Reviews
# 4888        79       37    79      16
# 6117         1        2     3       0
# 50198        2        2     0       0
# 14726        0        1     0       0
# 12314        1        0     0       0
# 46397        9       16    14       7
# 36505       75       39    45       3
# 51012        7       22    12       1
# 13537       62        6    51      29
# 14628        0        0     0       0

# %%
df.shape
# Out:
# (60000, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Release_Date', 'Developers', 'Summary',
#        'Platforms', 'Genres', 'Rating', 'Plays', 'Playing', 'Backlogs',
#        'Wishlist', 'Lists', 'Reviews'],
#       dtype='object')

# %%
df.drop(columns=['Rating','Lists','Plays','Playing',"Backlogs",'Wishlist','Reviews'], inplace=True)

# %%
df.sample(5)
# Out:
#        Unnamed: 0              Title  Release_Date                 Developers  \
# 36618       36618  Puzzle of Jellies  Dec 10, 2013  ['Qrostar', 'Jelly Crew']
# 32427       32427           UuultraC  Mar 24, 2022   ['ADELTA', 'MangaGamer']
# 9769         9769            Blindia  Oct 31, 2018                         []
# 25924       25924  Yet Another World  Nov 30, 2015                         []
# 24936       24936         Attack UFO  Dec 31, 1974                  ['Taito']
#
#                                                  Summary  \
# 36618  Originally released as Jelly no Puzzle for Win...
# 32427  An 18+ BL visual novel set in 1970's Soshigaya...
# 9769   Blindia is an abstract top-down shooter puzzle...
# 25924  Yet Another World - funny hardcore platformer ...
# 24936                                                NaN
#
#                             Platforms                                  Genres
# 36618                     ['Android']                              ['Puzzle']
# 32427                  ['Windows PC']  ['Adventure', 'Indie', 'Visual Novel']
# 9769                   ['Windows PC']                               ['Indie']
# 25924  ['Windows PC', 'Mac', 'Linux']                  ['Adventure', 'Indie']
# 24936                      ['Arcade']                                      []

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Title              0
# Release_Date       0
# Developers         0
# Summary         4954
# Platforms          0
# Genres             0
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Title           0
# Release_Date    0
# Developers      0
# Summary         0
# Platforms       0
# Genres          0
# dtype: int64

# %%
df.to_csv("modified_games.csv")

# %%
df = pd.read_csv("modified_games.csv")
df.drop(columns=['Unnamed: 0','Unnamed: 0.1'], inplace=True)
df.head(2)
# Out:
#                                      Title  Release_Date  \
# 0                               Elden Ring  Feb 25, 2022
# 1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
#
#                                           Developers  \
# 0     ['FromSoftware', 'Bandai Namco Entertainment']
# 1  ['Nintendo', 'Nintendo EPD Production Group No...
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  The Legend of Zelda: Breath of the Wild is the...
#
#                                            Platforms                   Genres
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...     ['Adventure', 'RPG']
# 1                       ['Wii U', 'Nintendo Switch']  ['Adventure', 'Puzzle']

# %%
df = df.drop_duplicates(subset=['Title'], keep='first')

# %%
print(df.shape)
print(f"Number of unique games: {df['Title'].nunique()}")
# Out:
# (37669, 6)
# Number of unique games: 37669

# %% [markdown]
# ### Cleaning Text(Handling text that appears in the format of a python list)

# %%
def parse_data(text):
    if not isinstance(text, str):
        return []
    if text.startswith('[') and text.endswith(']'):
        try:
            text = text.replace("'", "\"")
            parsed = json.loads(text)
            if isinstance(parsed, list):
                return parsed
        except:
            genres = re.findall(r"'([^']*)'", text)
            if genres:
                return genres
    if ',' in text:
        return [g.strip() for g in text.split(',')]
    return [text]

# %%
print("Preparing game data...")
df['genres_list'] = df['Genres'].apply(parse_data)
df['developers_list'] = df['Developers'].apply(parse_data)
df['game_content'] = df['Summary'].fillna('') 
df.sample(5)
# Out:
# Preparing game data...
#                        Title  Release_Date  \
# 51769         Blades of Time  Mar 06, 2012
# 46947  Luminous Arc Infinity  Aug 06, 2015
# 51559                Rooster           TBD
# 52643              Full Moon  Oct 20, 2009
# 16680     Narcissu 1st & 2nd  Apr 24, 2015
#
#                                Developers  \
# 51769  ['Konami', 'Gaijin Entertainment']
# 46947         ['Felistella', 'Marvelous']
# 51559                                  []
# 52643                      ['Bart Bonte']
# 16680                   ['Sekai Project']
#
#                                                  Summary  \
# 51769  Ayumi, the gorgeous gun and sword-wielding tre...
# 46947  The fourth game in the Luminous Arc series and...
# 51559             A 1994-1995 Amiga/PC top-down shooter.
# 52643  A rabbit wants fruit, but it's too dark to fin...
# 16680  This is a story of disease and suffering; of m...
#
#                                                Platforms  \
# 51769  ['Windows PC', 'Mac', 'Xbox 360', 'PlayStation...
# 46947                               ['PlayStation Vita']
# 51559                                                 []
# 52643                                    ['Web browser']
# 16680                     ['Windows PC', 'Mac', 'Linux']
#
#                                            Genres  \
# 51769  ['Adventure', 'Brawler', 'RPG', 'Shooter']
# 46947              ['RPG', 'Turn Based Strategy']
# 51559                                 ['Shooter']
# 52643                                  ['Puzzle']
# 16680                                   ['Indie']
#
#                               genres_list                 developers_list  \
# 51769  [Adventure, Brawler, RPG, Shooter]  [Konami, Gaijin Entertainment]
# 46947          [RPG, Turn Based Strategy]         [Felistella, Marvelous]
# 51559                           [Shooter]                              []
# 52643                            [Puzzle]                    [Bart Bonte]
# 16680                             [Indie]                 [Sekai Project]
#
#                                             game_content
# 51769  Ayumi, the gorgeous gun and sword-wielding tre...
# 46947  The fourth game in the Luminous Arc series and...
# 51559             A 1994-1995 Amiga/PC top-down shooter.
# 52643  A rabbit wants fruit, but it's too dark to fin...
# 16680  This is a story of disease and suffering; of m...

# %%
df['Content'] = df['Summary']
print("Building recommendation system...")
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
tfidf_matrix = tfidf.fit_transform(df['Content'])
sparse.save_npz('tfidf_matrix.npz', tfidf_matrix)
# Out:
# Building recommendation system...
