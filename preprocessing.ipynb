# %%
import pandas as pd
import numpy as np
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from scipy import sparse

# %%
df = pd.read_csv('games.csv')
df.sample(10)
# Out:
#        Unnamed: 0                                  Title  Release_Date  \
# 13589       13589             Fallen London: The Tempest  Aug 01, 2021
# 31327       31327                             The Letter  Jul 10, 2014
# 12551       12551                       Door 3: Insignia  Nov 15, 2021
# 19372       19372                        Madden NFL 2000  Jul 31, 1999
# 33125       33125  ESPN Winter X-Games Snowboarding 2002  Feb 01, 2001
# 27480       27480                         Ridge Racer 64  Feb 14, 2000
# 21198       21198                              Knotwords  Apr 28, 2022
# 11993       11993                          Glitch's Trip  Aug 25, 2020
# 51518       51518                    Image of Perfection  Jul 29, 2019
# 53298       53298                               G String  Oct 17, 2020
#
#                                          Developers  \
# 13589          ['Failbetter Games', 'Mary Goodden']
# 31327                          ['TreeFall Studios']
# 12551                                   ['SVGames']
# 19372                   ['EA Tiburon', 'EA Sports']
# 33125                                            []
# 27480  ['Nintendo', 'Nintendo Software Technology']
# 21198             ['Zach Gage', 'Jack Schlesinger']
# 11993          ['Ransacked Studios', 'Rogue Games']
# 51518                        ['Crystal Game Works']
# 53298             ['Eyaura', 'LunchHouse Software']
#
#                                                  Summary  \
# 13589  An addon for Fallen London. The Exceptional St...
# 31327  The Letter is a first person adventure horror ...
# 12551  Symbols have never had such an impact on a per...
# 19372  Madden NFL 2000 is a football video game. The ...
# 33125  The most authentic snowboarding game returns! ...
# 27480  Ridge Racer 64 gives Nintendo 64 owners a chan...
# 21198  Knotwords is a minimal and elegant logic puzzl...
# 11993  Travel through four epic worlds by jumping, sh...
# 51518  Image of Perfection is a creepy, atmospheric R...
# 53298  Myo Hyori, a gifted Korean teenage girl who mu...
#
#                                                Platforms  \
# 13589                                    ['Web browser']
# 31327                                          ['Wii U']
# 12551                                     ['Windows PC']
# 19372  ['Windows PC', 'Mac', 'PlayStation', 'Nintendo...
# 33125                               ['Game Boy Advance']
# 27480                                    ['Nintendo 64']
# 21198            ['Windows PC', 'Android', 'Mac', 'iOS']
# 11993  ['Windows PC', 'Mac', 'Linux', 'Xbox One', 'Ni...
# 51518                                     ['Windows PC']
# 53298                                     ['Windows PC']
#
#                                               Genres  Rating Plays Playing  \
# 13589                                  ['Adventure']     NaN     1       0
# 31327                                             []     0.9    21       0
# 12551               ['Adventure', 'Indie', 'Puzzle']     NaN     0       0
# 19372                                      ['Sport']     2.9    47       0
# 33125                                      ['Sport']     NaN     1       0
# 27480                                     ['Racing']     3.2   105       3
# 21198                ['Indie', 'Puzzle', 'Strategy']     3.9    87       9
# 11993   ['Adventure', 'Arcade', 'Indie', 'Platform']     NaN     1       1
# 51518  ['Adventure', 'Indie', 'RPG', 'Visual Novel']     NaN     0       0
# 53298              ['Adventure', 'Indie', 'Shooter']     3.5    53       5
#
#       Backlogs Wishlist Lists Reviews
# 13589        0        0     1       0
# 31327        8        2    11       4
# 12551        3        0     1       0
# 19372        7        1    12       4
# 33125        0        0     0       0
# 27480       31       25    39      10
# 21198        5        9    29       5
# 11993        1        1     0       0
# 51518       16        4    13       0
# 53298       72       86    32      11

# %%
df.shape
# Out:
# (60000, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Release_Date', 'Developers', 'Summary',
#        'Platforms', 'Genres', 'Rating', 'Plays', 'Playing', 'Backlogs',
#        'Wishlist', 'Lists', 'Reviews'],
#       dtype='object')

# %%
df.drop(columns=['Rating','Lists','Plays','Playing',"Backlogs",'Wishlist','Reviews'], inplace=True)

# %%
df.sample(5)
# Out:
#        Unnamed: 0                         Title  Release_Date  \
# 12352       12352               Sleeping Valley  Oct 08, 2016
# 6960         6960                     Extreme-G  Sep 30, 1997
# 14936       14936   Kyuuyaku Megami Tensei I-II  Mar 31, 1995
# 56373       56373           Marvel Heroes Omega  Jun 20, 2017
# 20651       20651  The Night of Fire Stealing 2  May 25, 2021
#
#                                              Developers  \
# 12352                                                []
# 6960   ['Acclaim Entertainment', 'Probe Entertainment']
# 14936                                ['Atlus Co., Ltd']
# 56373                                  ['Marvel Games']
# 20651                                                []
#
#                                                  Summary  \
# 12352  Sleeping Valley - a new arcade platformer game...
# 6960   Extreme-G is a futuristic racing game with an ...
# 14936  Kyuuyaku Megami Tensei I-II consists of Megami...
# 56373  Marvel Heroes Omega assembles one of the large...
# 20651  It's a difficult retro RPG game. No maps, no d...
#
#                                                Platforms  \
# 12352                                     ['Windows PC']
# 6960                                     ['Nintendo 64']
# 14936                                  ['Super Famicom']
# 56373  ['Windows PC', 'Mac', 'PlayStation 4', 'Xbox O...
# 20651                                     ['Windows PC']
#
#                                Genres
# 12352          ['Adventure', 'Indie']
# 6960   ['Racing', 'Shooter', 'Sport']
# 14936                         ['RPG']
# 56373                         ['RPG']
# 20651                   ['Adventure']

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Title              0
# Release_Date       0
# Developers         0
# Summary         4954
# Platforms          0
# Genres             0
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Title           0
# Release_Date    0
# Developers      0
# Summary         0
# Platforms       0
# Genres          0
# dtype: int64

# %%
df.to_csv("modified_games.csv")

# %%
df = pd.read_csv("modified_games.csv")
df.drop(columns=['Unnamed: 0','Unnamed: 0.1'], inplace=True)
df.head(2)
# Out:
#                                      Title  Release_Date  \
# 0                               Elden Ring  Feb 25, 2022
# 1  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
#
#                                           Developers  \
# 0     ['FromSoftware', 'Bandai Namco Entertainment']
# 1  ['Nintendo', 'Nintendo EPD Production Group No...
#
#                                              Summary  \
# 0  Elden Ring is a fantasy, action and open world...
# 1  The Legend of Zelda: Breath of the Wild is the...
#
#                                            Platforms                   Genres
# 0  ['Windows PC', 'PlayStation 4', 'Xbox One', 'P...     ['Adventure', 'RPG']
# 1                       ['Wii U', 'Nintendo Switch']  ['Adventure', 'Puzzle']

# %%
df = df.drop_duplicates(subset=['Title'], keep='first')

# %%
print(df.shape)
print(f"Number of unique games: {df['Title'].nunique()}")
# Out:
# (37669, 6)
# Number of unique games: 37669

# %% [markdown]
# ### Cleaning Text(Handling text that appears in the format of a python list)

# %%
def cleanText(text):
    if isinstance(text, str):
        if text.startswith('[') and text.endswith(']'):
            try:
                text = text.replace("'","\"")  # Replace single quotes with double quotes
                parsed = json.loads(text)
                if isinstance(parsed, list):
                    return ' '.join(parsed)
            except:
                text = text[1:-1].replace("'", "").replace('"', '')
        return text
    return ''

# %%
df['Genres'] = df['Genres'].apply(cleanText)
df['Summary'] = df['Summary'].apply(cleanText)
df['Developers'] = df['Developers'].apply(cleanText)
df.sample(5)
# Out:
#                       Title  Release_Date            Developers  \
# 12647                Opoona  Nov 01, 2007       Koei ArtePiazza
# 12835              Los Cops           TBD
# 53294              Girls VR  Sep 28, 2018
# 8481               Gravitas  Aug 23, 2019  Galaxy Shark Studios
# 47187  Fair Deal: Las Vegas  Dec 21, 2018     Gronzragüer Games
#
#                                                  Summary  \
# 12647  While on an interplanetary family vacation, th...
# 12835  Become a detective in a multi-genre non-linear...
# 53294  Four beautiful girls are dancing just for you,...
# 8481   Gravitas is a short first-person puzzle platfo...
# 47187  “Fair Deal: Las Vegas” is a side scroller 2D p...
#
#                    Platforms  \
# 12647                ['Wii']
# 12835                     []
# 53294         ['Windows PC']
# 8481          ['Windows PC']
# 47187  ['Windows PC', 'Mac']
#
#                                                   Genres
# 12647                                Platform Puzzle RPG
# 12835                                    Adventure Indie
# 53294  Adventure Indie Racing RPG Simulator Sport Str...
# 8481                                     Adventure Indie
# 47187                                              Indie

# %%
df['Content'] = df['Genres'] + ' ' + df['Developers']


#heavy emphasis on genres   and developers

# %% [markdown]
# ### Creating TFIDF Matrix

# %%
tfidf = TfidfVectorizer(stop_words='english', 
                       max_features=5000,
                       ngram_range=(1,2))
tfidf_matrix = tfidf.fit_transform(df['Content'])
tfidf_matrix.shape
sparse.save_npz('tfidf_matrix.npz', tfidf_matrix)
print("TF-IDF matrix saved successfully to 'tfidf_matrix.npz'")
# Out:
# TF-IDF matrix saved successfully to 'tfidf_matrix.npz'
